# %%
import pandas as pd
import matplotlib.pyplot as plt
path = "ToyotaCorolla.csv"

# %%
#import pandas as pd
df = pd.read_csv("ToyotaCorolla.csv")
from pandas.plotting import scatter_matrix
#import matplotlib.pyplot as plt
names = ['Price', 'Age', 'KM', 'HP', 'CC', 'Doors', 'Weight']
scatter_matrix(df)
plt.show()

# %%
df
# Out:
#       Price  Age     KM FuelType   HP  MetColor  Automatic    CC  Doors  \
# 0     13500   23  46986   Diesel   90         1          0  2000      3
# 1     13750   23  72937   Diesel   90         1          0  2000      3
# 2     13950   24  41711   Diesel   90         1          0  2000      3
# 3     14950   26  48000   Diesel   90         0          0  2000      3
# 4     13750   30  38500   Diesel   90         0          0  2000      3
# ...     ...  ...    ...      ...  ...       ...        ...   ...    ...
# 1431   7500   69  20544   Petrol   86         1          0  1300      3
# 1432  10845   72  19000   Petrol   86         0          0  1300      3
# 1433   8500   71  17016   Petrol   86         0          0  1300      3
# 1434   7250   70  16916   Petrol   86         1          0  1300      3
# 1435   6950   76      1   Petrol  110         0          0  1600      5
#
#       Weight
# 0       1165
# 1       1165
# 2       1165
# 3       1165
# 4       1170
# ...      ...
# ...

# %%
#import pandas as pd 
#import matplotlib.pyplot as plt
ds=pd.read_csv("ToyotaCorolla.csv")
plt.scatter(ds['Price'],ds['Age'],color=['Yellow'])
plt.xlabel('Price')
plt.ylabel('Age')
plt.title("Price VS Age")
plt.show()

# %%
#import pandas as pd
#import matplotlib.pyplot as plt

# Assuming the 'ToyotaCorolla.csv' file is in the same directory as this script
#path = "ToyotaCorolla.csv"
names = ['Price', 'Age', 'KM', 'HP', 'CC', 'Doors', 'Weight']
data = pd.read_csv(path, names=names)

# Convert non-numeric columns to numeric data types
data['Age'] = pd.to_numeric(data['Age'], errors='coerce')
data['KM'] = pd.to_numeric(data['KM'], errors='coerce')
data['HP'] = pd.to_numeric(data['HP'], errors='coerce')
data['CC'] = pd.to_numeric(data['CC'], errors='coerce')
data['Doors'] = pd.to_numeric(data['Doors'], errors='coerce')
data['Weight'] = pd.to_numeric(data['Weight'], errors='coerce')

# Plot the histogram for numeric columns only
data.hist()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

path = "ToyotaCorolla.csv"
names = ['Price', 'Age', 'KM', 'HP', 'CC', 'Doors', 'Weight']
data = pd.read_csv(path, names=names)

data['Age'] = pd.to_numeric(data['Age'], errors='coerce')
data['KM'] = pd.to_numeric(data['KM'], errors='coerce')
data['HP'] = pd.to_numeric(data['HP'], errors='coerce')
data['CC'] = pd.to_numeric(data['CC'], errors='coerce')
data['Doors'] = pd.to_numeric(data['Doors'], errors='coerce')
data['Weight'] = pd.to_numeric(data['Weight'], errors='coerce')


column_name = input("Input the colomn name ")


plt.hist(data[column_name], bins=10, color='skyblue', edgecolor='black')  # You can adjust the number of bins as needed
plt.title('Histogram of {}'.format(column_name))
plt.xlabel(column_name)
plt.ylabel('Frequency')
plt.grid(True)
plt.show()
# Out:
# Input the colomn name KM

# %%
import pandas as pd
import matplotlib.pyplot as plt

path = "ToyotaCorolla.csv"
names = ['Price', 'Age', 'KM', 'HP', 'CC', 'Doors', 'Weight']
data = pd.read_csv(path, names=names, na_values='?')

data = data.apply(pd.to_numeric, errors='coerce')

column_name = 'Price'

# Drop rows with NaN values in the 'Price' column
data.dropna(subset=[column_name], inplace=True)

plt.hist(data[column_name], bins=10, color='skyblue', edgecolor='black')
plt.title('Histogram of {}'.format(column_name))
plt.xlabel(column_name)
plt.ylabel('Frequency')
plt.grid(True)
plt.show()
